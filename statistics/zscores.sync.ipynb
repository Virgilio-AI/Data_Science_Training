# %%
# %config InlineBackend.figure_formats = ['svg']
from numpy.random import randint
import numpy as np # for importing numpy
import pandas as pd # for importing pandas
# %matplotlib inline
import random
from scipy import stats
import matplotlib.pyplot as plt

# %%
facebook_mean = 200
facebook_sigma = 30

facebook_friends = np.random.normal(facebook_mean, facebook_sigma, 10000)


ffzscore = ( 227 - facebook_mean ) / facebook_sigma

# %%
ffzscore
# Out:
# 0.9

# %%
# then you can plot for more convenience

x = np.linspace(-4, 4, 100)
y = stats.norm.pdf(x)
plt.plot(x, y)
plt.fill_between(x, y, where=( x < ffzscore ), color='red')

# to get the probability of the area to the left of zscore you do
pl = stats.norm.cdf(ffzscore)
# this is usually is done via integration or via a table for lookup

# %%
pl
# Out:
# 0.8159398746532405

# %%
twitter_mu = 100
twitter_sigma = 20

facebook_mu = 200
facebook_sigma = 30

# %%
twitter_followers = np.random.normal(twitter_mu, twitter_sigma, 10000)
facebook_friends = np.random.normal(facebook_mu, facebook_sigma, 10000)

# %%
twitter_followers = 227

# %%
zscores = ( twitter_followers - twitter_mu ) / twitter_sigma

# %%
facebook_friends = zscores * facebook_sigma + facebook_mu

# %%
facebook_friends
# Out:
# 390.5
